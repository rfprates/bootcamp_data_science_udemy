# %% [markdown]
# # Exercício 7

# %% [markdown]
# Use a função pd.read_html() para obter os principais indicadores econômicos dos EUA entre 1980-2020 (estimativa). Use como referência o link: https://en.wikipedia.org/wiki/Economy_of_the_United_States

# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_the_United_States')[0]

# %%
df
# Out:
#                                                     0  \
# 0   New York City, the world’s principal financial...
# 1                                            Currency
# 2                                         Fiscal year
# 3                                 Trade organizations
# 4                                       Country group
# 5                                          Statistics
# 6                                          Population
# 7                                                 GDP
# 8                                            GDP rank
# 9                                          GDP growth
# 10                                     GDP per capita
# 11                                GDP per capita rank
# 12                                      GDP by sector
# 13                                   GDP by component
# 14                                    Inflation (CPI)
# 15                      Population below poverty line
# ...

# %% [markdown]
# # Exercício 8
#
# Salve a tabela anterior no formato CSV.

# %%
df.to_csv('Infos_USA.csv', sep = ';', index = False)
