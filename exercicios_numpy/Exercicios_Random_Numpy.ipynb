# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercício 1
#
# Gere uma distribuição normal aleatória de ordem 4 x 5. Armazene o resultado em uma variável.

# %%
a = np.random.normal(size = (4,5))

# %% [markdown]
# # Exercício 2
#
# Gere uma distribuição normal aleatória com de ordem 20 x 5, com média 10 e desvio padrão 3. Armazene o resultado em uma variável. Em seguida crie um DataFrame a partir dos dados criados.

# %%
# distribuição normal
data = np.random.normal(loc = 10, scale = 3, size = (20,5))

# criando o DataFrame a partir da matriz criada acima, utilizando a biblioteca Pandas (pd), com colunas nomeadas em uma lista de A até E e linhas que vão de 1 até a 20.
df = pd.DataFrame(data, columns = list('ABCDE'), index = range(1,21))
df
# Out:
#             A          B          C          D          E
# 1    6.586592  11.933234  12.509171  16.008406   9.215172
# 2    7.640892  16.674499   9.595135   9.941688   9.329635
# 3   10.432346   7.984908   8.485224   9.268494   8.507072
# 4    9.978380  10.941098  10.803057   8.222479   9.790895
# 5    8.836267   9.063563  11.507746   5.780059   9.591670
# 6    9.227935   6.976264   7.713325  13.103966  14.091939
# 7    9.580128  12.313794   7.323881   9.655061   9.248192
# 8   12.041092  10.435638  13.796969  12.341595  10.450283
# 9    7.132485  11.371137   8.749971  11.538384   9.357641
# 10  10.984932   7.618343   6.588246  10.165857   9.308290
# 11  11.050909   6.670087  10.668626   6.087771  12.362614
# 12  10.371742   6.987897   8.242321  11.641556  12.526328
# 13   7.720966  17.664866   5.417300  16.827996  13.508129
# 14  14.587324  13.840864   6.284175   7.055417  10.824731
# 15   7.724278   6.395005  14.830501   6.328617  10.676465
# 16   9.927158  13.374019  10.589804   9.599841  14.127100
# 17  19.071309  10.877378   7.743941   7.665901  14.275937
# 18   3.647739   8.752804   4.864383   7.469873   8.224803
# 19  14.605155  13.452634  12.294060  14.231621   8.470103
# 20  13.646234   5.509159  11.665295   9.625832  10.229033

# %% [markdown]
# # Exercício 3
#
# Gere uma distribuição normal padrão e utilize o módulo Seaborn para construir uma visualização dos dados. A amostra deve conter 3000 números. Use a função distplot() do módulo Seaborn e importe também.

# %%
data = np.random.normal(size = 3000)

df = pd.DataFrame(data)

# gerando uma visualização dos dados usando a biblioteca Seaborn

# plotando um histograma dos dados
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
#plotando um gráfico com a linha de dispersão dos dados (kde)
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Exercício 4
#
# A distribuição binomial é uma distribuição discreta de probabilidade e descreve resultados binários, como sucesso e fracasso ou cara e coroa, por exemplo. Podemos criar dados aleatórios para esta distribuição com a função np.random.binomial().Sendo:
#
# * n: número de tentativas;
#
# * p: probabilidade de ocorrência de cada tentativa;
#
# * size: tamanho do vetor retornado (shape).
#
# Com base nestas informações:
#
# Gere números aleatórios seguindo uma distribuição binomial, com 6 tentativas, em que a probabilidade de ocorrência de cada tentativa é 0.5, e tamanho 100. Armazene os dados em uma variável, 'data1'.
#
# Gere números aleatórios seguindo uma distribuição binomial, com 2 tentativas, em que a probabilidade de ocorrência de cada tentativa é 0.8, e tamanho 1000. Armazene os dados em uma variável, 'data2'.

# %%
data1 = np.random.binomial(n = 6, p = 0.5, size = 100)
data2 = np.random.binomial(n = 2, p = 0.8, size = 1000)

# %% [markdown]
# # Exercício 5
#
# Use o módulo Seaborn para visualizar a distribuição de números aleatórios oriunda de uma distribuição binomial, com 6 tentativas, probabilidade 0.5 e tamanho 3000.

# %%
data = np.random.binomial(n = 6, p = 0.5, size = 3000)

df = pd.DataFrame(data)

# plotando o gráfico
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# # Exercício 6
#
# A distribuição uniforme é uma distribuição contínua de probabilidade, com importantes aplicações em estatística. Gere uma amostra da distribuição uniforme de shape 3 x 3.
# Dica: use np.random.uniform().

# %%
data = np.random.uniform(size = (3,3))

df = pd.DataFrame(data, columns = list('ABC'), index = range(1,4))

df.head()
# Out:
#           A         B         C
# 1  0.933579  0.018863  0.216195
# 2  0.200516  0.349913  0.340396
# 3  0.010076  0.918744  0.783342

# %% [markdown]
# # Exercício 7
#
# Use o módulo Seaborn para visualizar a distribuição de números aleatórios oriunda de uma distribuição uniforme, de tamanho 1000.

# %%
data = np.random.uniform(size = 1000)

sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Exercício 8
#
# Gere um array com números aleatórios entre -1000 e 3000, de shape (30, 5).

# %%
data_int = np.random.randint(low = -1000, high = 3000, size = (30,5))

# %% [markdown]
# # Exercício 9
#
# Gere um array de shape 30 x 5 com números entre 0 e 4, inclusive.

# %%
array = np.random.randint(low = 0, high = 5, size = (30,5))
print(array)
# Out:
# [[2 1 0 4 4]
#  [3 3 1 4 2]
#  [4 2 1 1 2]
#  [4 2 1 2 0]
#  [2 0 3 1 0]
#  [1 4 4 4 4]
#  [3 3 4 2 1]
#  [0 0 4 0 2]
#  [0 1 4 3 2]
#  [3 0 3 3 3]
#  [1 2 1 3 3]
#  [3 2 2 4 4]
#  [2 4 3 1 2]
#  [3 1 4 4 2]
#  [4 1 0 4 4]
#  [1 2 3 2 0]
#  [1 0 3 2 1]
#  [3 2 3 2 2]
#  [3 3 0 4 4]
#  [0 3 4 3 0]
#  [3 1 2 0 3]
#  [4 1 0 2 0]
#  [1 3 3 2 2]
#  [4 0 0 3 0]
#  [2 3 0 3 4]
#  [2 1 0 3 1]
#  [1 3 1 0 2]
#  [4 3 2 2 4]
#  [2 2 4 0 1]
#  [4 3 2 4 3]]

# %% [markdown]
# # Exercício 10
#
# Gere um array de números inteiros com limites superiores diferentes (100, 300, 50, 10000), mas com valor mínimo 10.

# %%
arr = np.random.randint(low = 10, high = [100,300,50,10000])

# %% [markdown]
# # Exercício 11
#
# Utilize a função np.random.rand() para gerar um array 10 x 5. Lembre que esta função gera por padrão números aleatórios de acordo com uma distribuição uniforme no intervalo [0,1]. Em seguida mostre na tela a média, desvio padrão e mediana do array gerado.

# %%
array = np.random.rand(10,5)
print(array)
print()

media = np.mean(array)
mediana = np.median(array)
desvio_padrao = np.std(array)
print(f'Média dos elementos do vetor = {media}')
print(f'Mediana dos elementos do vetor = {mediana}')
print(f'Desvio padrão dos elementos do vetor = {desvio_padrao}')
# Out:
# [[0.49331672 0.97517693 0.73398591 0.28463784 0.86614963]
#  [0.31073291 0.2022173  0.75896186 0.16043494 0.45201386]
#  [0.09535629 0.23771209 0.80083839 0.05162941 0.8294279 ]
#  [0.04740899 0.38200952 0.23347405 0.3468855  0.84947145]
#  [0.38044528 0.88004657 0.32373686 0.30431197 0.71794817]
#  [0.60338968 0.39443762 0.12767882 0.74201899 0.67110457]
#  [0.22027187 0.15343718 0.94057935 0.15432391 0.7454261 ]
#  [0.50849945 0.64552281 0.08021846 0.63307401 0.68237639]
#  [0.94004061 0.4873505  0.29877716 0.8621037  0.50049678]
#  [0.26228384 0.0770587  0.14437168 0.95549335 0.72637134]]
#
# Média dos elementos do vetor = 0.48550074469298715
# Mediana dos elementos do vetor = 0.46968218103911447
# Desvio padrão dos elementos do vetor = 0.2883802857038089

# %% [markdown]
# # Exercício 12
#
# Use a função np.random.randn() para gerar um array com números aleatórios de uma distribuição normal padrão, de shape 30 x 3. Seguidamente, crie um DataFrame com os dados criados e gere uma visualização da distribuição de probabilidade de cada coluna com o módulo Seaborn.

# %%
data = np.random.randn(30,3)

df = pd.DataFrame(data, columns = list('ABC'), index = range(1,31))

df.head()
# Out:
#           A         B         C
# 1 -0.281212 -0.064370 -0.750507
# 2 -1.454710  1.256654  0.261760
# 3  1.826501 -0.350232 -0.757581
# 4  0.605901 -1.573055 -0.535426
# 5  1.558204  0.614778  1.194966

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Exercício 13
#
# Gere um array com 800 números aleatórios de acordo com uma distribuição exponencial padrão. Use a função np.random.standard_exponential().

# %%
array = np.random.standard_exponential(size = 800)

# %% [markdown]
# # Exercício 14
#
# A distribuição de Poisson é uma distribuição discreta de probabilidade. Esta distribuição descreve quantas vezes um determinado evento pode ocorrer em um tempo especificado. A biblioteca NumPy permite gerar números aleatórios desta distribuição com a função np.random.poisson(). Gere uma distribuição aleatória de shape 50 x 3, com número conhecido de ocorrências igual a 5.

# %%
arr = np.random.poisson(5, size = (50,3))
print(arr)
# Out:
# [[ 7  8  2]
#  [ 3  7  2]
#  [ 5  5  4]
#  [ 5  7  7]
#  [ 7  5  4]
#  [ 3  7  7]
#  [ 8  3  6]
#  [ 6  3  4]
#  [ 3  7  3]
#  [ 8  6  3]
#  [ 4  3  5]
#  [ 5  6  5]
#  [ 3  5  4]
#  [ 4  5  8]
#  [ 6  7  8]
#  [ 5  6  4]
#  [ 7  6  3]
#  [ 7  5  5]
#  [ 3  5  2]
#  [ 6  7  4]
#  [ 6  7  2]
#  [ 6  5  5]
#  [ 7  6  5]
#  [ 4  6  4]
#  [ 5  3  2]
#  [ 6  6  5]
#  [ 5  5  4]
#  [ 7  8  8]
#  [ 3  3  7]
#  [ 8  4  6]
#  [ 5  7  3]
#  [ 9  4  4]
#  [ 1  5  3]
#  [ 6  7 11]
#  [ 5  6  7]
#  [ 0  6  5]
#  [ 7  6  9]
#  [ 2  6  5]
#  [ 5  3  8]
#  [ 4  5  5]
#  [ 7  4  2]
#  [ 2  8  8]
#  [ 5  5  7]
#  [ 4  6  4]
#  [ 5  2  4]
#  [ 3  3  5]
#  [ 5 10  6]
#  [ 8  7  5]
#  [ 9  6  5]
#  [ 3  9  8]]

# %% [markdown]
# # Exercício 15
#
# Gere uma distribuição aleatória de Poisson com 10.000 amostras, em que o número conhecido de ocorrências é igual 3. Armazene os dados em um objeto Pandas Series.

# %%
array = np.random.poisson(3, size = 10000)

series = pd.Series(array, name = 'Possion')

series.head()
# Out:
# 0    5
# 1    4
# 2    2
# 3    1
# 4    2
# Name: Possion, dtype: int64

# %%
# plotando um gráfico de histograma junto com a linha de dispersão kde
sns.histplot(series, kde = True)
# Out:
# <Axes: xlabel='Possion', ylabel='Count'>

# %% [markdown]
# # Exercício 16
#
# A função np.random.choice() gera uma amostra aleatória de um array unidimensional. Gere uma amostra aleatória de tamanho 10, a partir das letras 'a', 'b', 'c', 'd'.

# %%
array = np.random.choice(list('abcd'),size = 10)
print(array)
# Out:
# ['a' 'd' 'a' 'd' 'b' 'b' 'b' 'd' 'a' 'b']

# %% [markdown]
# # Exercício 17
#
# Gere um DataFrame com 7 colunas e 100 linhas, com as seguintes características:
#
# * a coluna 'A' segue uma distribuição normal padrão;
#
# * a coluna 'B' segue uma distribuição uniforme;
#
# * a coluna 'C' segue uma distribuição binomial, com 6 tentativas e probabilidade de sucesso 0.6;
#
# * a coluna 'D' segue uma distribuição exponencial padrão;
#
# * a coluna 'E' segue uma distribuição de Poisson com número conhecido de ocorrências igual a 10;
#
# * a coluna 'F' segue uma distribuição normal de média 100 e desvio padrão 15;
#
# * a coluna 'G' possui números aleatórios inteiros entre 50 e 3000.

# %%
n = 100  #quantidade de observações

data = {
    'A': np.random.normal(size = n),
    'B': np.random.uniform(size = n),
    'C': np.random.binomial(n = 6, p = 0.6, size = n),
    'D': np.random.standard_exponential(size = n),
    'E': np.random.poisson(lam = 10, size = n),
    'F': np.random.normal(loc = 100, scale = 15, size = n),
    'G': np.random.randint(low = 50, high = 3000, size = n)}

df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    float64
#  1   B       100 non-null    float64
#  2   C       100 non-null    int64
#  3   D       100 non-null    float64
#  4   E       100 non-null    int64
#  5   F       100 non-null    float64
#  6   G       100 non-null    int64
# dtypes: float64(4), int64(3)
# memory usage: 5.6 KB

# %% [markdown]
# #Exercício 18
#
# * Gere uma amostra da distribuição Qui-Quadrado com 3 graus de liberdade e shape 5 x 5;
#
# * Gere uma amostra da distribuição Qui-Quadrado com 2 graus de liberdade e tamanho 2.000 e plot um gráfico para visualizar a distribuição de probabilidade gerada;
#
# * Gere uma amostra de uma distribuição Exponencial com scale 5 e shape 2 x 2.

# %%
# a)
array = np.random.chisquare(3, size = (5,5))

# b)
array2 = np.random.chisquare(2, size = 2000)

df = pd.Series(array2)

sns.histplot(df, kde = True)

# c)
array3 = np.random.exponential(scale = 5, size = (2,2))

# %% [markdown]
# # Exercício 19
#
# A distribuição logística é amplamente utilizada em Machine Learning e Redes Neurais. Gere um vetor com números aleatórios de uma amostra de tamanho 100, gerado por meio de uma distribuição logística com média 5 e desvio padrão 0.9.

# %%
vetor = np.random.logistic(loc = 5, scale = 0.9, size = 100)

# %% [markdown]
# # Exercício 20
#
# Construa dois vetores de tamanho 100, com média 1 e desvio padrão 0.5, sendo que o primeiro segue uma distribuição normal, ao passo que o segundo vetor segue uma distribuição logística. Em seguida construa um DataFrame com os números aleatórios criados e gere um gráfico único que mostre ambas as distribuições aleatórias geradas.

# %%
n = 100
media = 1
desvio_padrao = 0.5

dados = {
    'Normal':np.random.normal(loc = media, scale = desvio_padrao, size = n),
    'Logistic':np.random.logistic(loc = media, scale = desvio_padrao, size = n)
}

# criando o DataFrame
df = pd.DataFrame(dados)

# plotando o gráfico

sns.kdeplot(df)
plt.title('Comparação Distribuição Normal x Distribuição Logística')
plt.xlabel('Valores')
plt.show()
